# %%
import tensorflow as tf
import ccc
from ccc.model import GeneralizedCCCModel
from ccc import utils

print("Imports successful!")
print(f"TensorFall version: {tf.__version__}")
# Out:
# 2026-01-09 14:52:32.060559: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-09 14:52:32.093506: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Imports successful!
# TensorFall version: 2.20.0
# 2026-01-09 14:52:32.776883: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
N = 200
P = 350
T = 500

batches=32

# %%
X = tf.random.normal([32,N, T])
Y = tf.random.normal([32,P, T])

# %%
utils.helper_functions.svd_reconstruct_from_full
# Out:
#   Cell In[2], line 1
#     utils.helper_functions.
#                            ^
# SyntaxError: invalid syntax
